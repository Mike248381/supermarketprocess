# %%
category = "furniture"


returnedValue = dbutils.notebook.run(
        '/Workspace/Superstore Production/Superstore Process/superstore_process', 
        600, 
        {"category": category}
                                         )

display(returnedValue)
